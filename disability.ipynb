# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("C:/Users/pravi/Desktop/PROJECTS/Disability/DHDS.csv")

# %%
df.head()
# Out:
#    Year LocationAbbr   LocationDesc DataSource              Category  \
# 0  2018         HHS3   HHS Region 3      BRFSS  Disability Estimates
# 1  2018           CA     California      BRFSS  Disability Estimates
# 2  2018           MN      Minnesota      BRFSS  Disability Estimates
# 3  2018           NY       New York      BRFSS  Disability Estimates
# 4  2018           NH  New Hampshire      BRFSS  Disability Estimates
#
#                                            Indicator  \
# 0  Disability status and types among adults 18 ye...
# 1  Disability status and types among adults 18 ye...
# 2  Disability status and types among adults 18 ye...
# 3  Disability status and types among adults 18 ye...
# 4  Disability status and types among adults 18 ye...
#
#                         Response Data_Value_Unit          Data_Value_Type  \
# 0            Mobility Disability               %  Age-adjusted Prevalence
# 1              Vision Disability               %  Age-adjusted Prevalence
# ...

# %%
df.describe()
# Out:
#               Year   Data_Value  Data_Value_Alt  Data_Value_Footnote_Symbol  \
# count  1544.000000  1544.000000     1544.000000                         0.0
# mean   2016.994819    18.125194       18.125194                         NaN
# std       0.817802    22.437918       22.437918                         NaN
# min    2016.000000     1.900000        1.900000                         NaN
# 25%    2016.000000     5.100000        5.100000                         NaN
# 50%    2017.000000     9.000000        9.000000                         NaN
# 75%    2018.000000    19.925000       19.925000                         NaN
# max    2018.000000    81.300000       81.300000                         NaN
#
#        Data_Value_Footnote  Low_Confidence_Limit  High_Confidence_Limit  \
# count                  0.0           1544.000000            1544.000000
# mean                   NaN             17.220466              19.100065
# ...

# %%
df.shape
# Out:
# (1544, 31)

# %%
df = df.drop(["Data_Value_Footnote_Symbol","Data_Value_Footnote","StratificationCategory2","Stratification2",
              "StratificationCategoryID2","StratificationID2","DataSource","Data_Value_Unit","Category","Geolocation",
              "LocationAbbr","Data_Value_Type","StratificationCategory1","Stratification1","ResponseID","DataValueTypeID",
              "StratificationCategoryID1","StratificationID1"],axis=1)

# %%
df.shape
# Out:
# (1544, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1544 entries, 0 to 1543
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Year                   1544 non-null   int64
#  1   LocationDesc           1544 non-null   object
#  2   Indicator              1544 non-null   object
#  3   Response               1544 non-null   object
#  4   Data_Value             1544 non-null   float64
#  5   Data_Value_Alt         1544 non-null   float64
#  6   Low_Confidence_Limit   1544 non-null   float64
#  7   High_Confidence_Limit  1544 non-null   float64
#  8   Number                 1544 non-null   int64
#  9   WeightedNumber         1544 non-null   int64
#  10  CategoryID             1544 non-null   object
#  11  IndicatorID            1544 non-null   object
#  12  LocationID             1544 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# memory usage: 156.9+ KB

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["Indicator_encode"] = le.fit_transform(df["Indicator"])
df["Response_encode"] = le.fit_transform(df["Response"])
df.head(2)
# Out:
#    Year  LocationDesc                                          Indicator  \
# 0  2018  HHS Region 3  Disability status and types among adults 18 ye...
# 1  2018    California  Disability status and types among adults 18 ye...
#
#               Response  Data_Value  Data_Value_Alt  Low_Confidence_Limit  \
# 0  Mobility Disability        11.8            11.8                  11.3
# 1    Vision Disability         4.7             4.7                   4.2
#
#    High_Confidence_Limit  Number  WeightedNumber CategoryID IndicatorID  \
# 0                   12.2    8006         3104208     DISEST    STATTYPE
# 1                    5.3     581         1429797     DISEST    STATTYPE
#
#    LocationID  Indicator_encode  Response_encode
# 0          82                 0                4
# 1           6                 0                7
